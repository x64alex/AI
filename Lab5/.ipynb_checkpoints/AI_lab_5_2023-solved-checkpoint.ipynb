# %% [markdown]
# ## A.I. Assignment 5
#
# ## Learning Goals
#
# By the end of this lab, you should be able to:
# * Get more familiar with tensors in pytorch
# * Create a simple multilayer perceptron model with pytorch
# * Visualise the parameters
#
#
# ### Task
#
# Build a fully connected feed forward network that adds two bits. Determine the a propper achitecture for this network (what database you use for this problem? how many layers? how many neurons on each layer? what is the activation function? what is the loss function? etc)
#
# Create at least 3 such networks and compare their performance (how accurate they are?, how farst they are trained to get at 1 accuracy?)
#
# Display for the best one the weights for each layer.

# %%
import torch
import torch.nn as nn
from collections import OrderedDict

# %%
# Input and output for networks
data_in = torch.Tensor([[0, 0], [0, 1], [1, 0], [1, 1]])
data_target = torch.Tensor([[0, 0], [0, 1], [0, 1], [1, 0]])

# %%
model2Linear = nn.Sequential(OrderedDict([
            ('linear1', nn.Linear(2, 5)),          
            ('sigmoid1', nn.Sigmoid()),          
            ('linear2', nn.Linear(5, 2)),          
            ('sigmoid2', nn.Sigmoid())
]))
model3Linear = nn.Sequential(OrderedDict([
            ('linear1', nn.Linear(2, 10)),          
            ('sigmoid1', nn.Sigmoid()),          
            ('linear2', nn.Linear(10, 20)),          
            ('sigmoid2', nn.Sigmoid()),
            ('linear3', nn.Linear(20, 2)),          
            ('sigmoid3', nn.Sigmoid())
]))
model4Linear = nn.Sequential(OrderedDict([
            ('linear1', nn.Linear(2, 2)),          
            ('sigmoid1', nn.Sigmoid()),          
            ('linear2', nn.Linear(2, 3)),          
            ('sigmoid2', nn.Sigmoid()),
            ('linear3', nn.Linear(3, 4)),          
            ('sigmoid3', nn.Sigmoid()),
            ('linear4', nn.Linear(4, 2)),          
            ('sigmoid4', nn.Sigmoid())
]))

# %%
def calculatePerformancePrint(model, num_epochs, data_in, data_target):
    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

    for epoch in range(num_epochs):
        # Forward pass
        outputs = model(data_in)
        loss = criterion(outputs, data_target)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print the loss every 100 epochs
        if (epoch+1) % 100 == 0:
            print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))

    with torch.no_grad():
        predicted = model(data_in)
        predicted = torch.round(predicted)
        accuracy = (predicted == data_target).sum().item() / (len(data_target) * len(data_target[0]))
        print('Test Accuracy: {:.2f}%'.format(accuracy*100))    

    for name, param in model.named_parameters():
        print(name, param.data)
        
    data_pred = model(data_in)
    data_pred = torch.round(data_pred)
    print(data_pred)

# %%
calculatePerformancePrint(model2Linear, 1000, data_in, data_target)
# Out:
# Epoch [100/1000], Loss: 0.1347
# Epoch [200/1000], Loss: 0.1340
# Epoch [300/1000], Loss: 0.1334
# Epoch [400/1000], Loss: 0.1327
# Epoch [500/1000], Loss: 0.1321
# Epoch [600/1000], Loss: 0.1314
# Epoch [700/1000], Loss: 0.1308
# Epoch [800/1000], Loss: 0.1301
# Epoch [900/1000], Loss: 0.1294
# Epoch [1000/1000], Loss: 0.1287
# Test Accuracy: 87.50%
# linear1.weight tensor([[-1.8309, -1.3393],
#         [-0.3950, -2.1711],
#         [ 1.5772,  1.5724],
#         [-1.7475, -0.3090],
#         [ 1.1435,  1.2802]])
# linear1.bias tensor([ 1.9440,  1.0260, -0.6180,  0.5777, -1.0742])
# linear2.weight tensor([[-3.2975, -2.6356,  2.1628, -2.2680,  2.1792],
#         [ 0.2713,  0.0477,  0.8466,  0.0661, -0.0578]])
# linear2.bias tensor([-0.6282, -0.7128])
# tensor([[0., 0.],
#         [0., 1.],
#         [0., 1.],
#         [1., 1.]], grad_fn=<RoundBackward0>)

# %%
calculatePerformancePrint(model3Linear, 1000, data_in, data_target)
# Out:
# Epoch [100/1000], Loss: 0.2167
# Epoch [200/1000], Loss: 0.2165
# Epoch [300/1000], Loss: 0.2163
# Epoch [400/1000], Loss: 0.2161
# Epoch [500/1000], Loss: 0.2159
# Epoch [600/1000], Loss: 0.2157
# Epoch [700/1000], Loss: 0.2155
# Epoch [800/1000], Loss: 0.2152
# Epoch [900/1000], Loss: 0.2149
# Epoch [1000/1000], Loss: 0.2146
# Test Accuracy: 62.50%
# linear1.weight tensor([[ 0.5650,  0.8210],
#         [-0.0971,  0.2153],
#         [ 0.6013, -0.1252],
#         [ 0.0762,  0.2461],
#         [-0.6801, -0.5085],
#         [ 0.2361,  0.2272],
#         [ 0.1687,  0.3762],
#         [-0.0522,  0.0069],
#         [ 0.1582,  0.5532],
#         [ 0.0642, -0.7404]])
# linear1.bias tensor([-0.5882,  0.0554, -0.6414,  0.2920,  0.4856, -0.6782, -0.1968, -0.5767,
#         -0.4760,  0.6518])
# linear2.weight tensor([[-0.0263, -0.2938,  0.2726,  0.0780,  0.1267,  0.0585,  0.0174,  0.0980,
#           0.1168, -0.0922],
#         [ 0.0565,  0.0287,  0.0076, -0.1944, -0.1587, -0.1042,  0.2403,  0.1621,
#           0.1833,  0.2035],
#         [-0.0106, -0.2536, -0.2408, -0.0907,  0.1916, -0.1032, -0.2204, -0.1017,
#           0.0352,  0.0874],
#         [-0.2250, -0.0431,  0.1839,  0.2741,  0.2707, -0.3256, -0.3299, -0.0766,
#           0.2228,  0.2053],
#         [-0.2676,  0.1036,  0.2798, -0.0581,  0.3438, -0.0142,  0.0513,  0.0937,
#           0.1383,  0.2456],
#         [ 0.0623,  0.2820, -0.1202, -0.0768,  0.2742,  0.1180,  0.2279,  0.1099,
#          -0.0409,  0.1030],
#         [ 0.1727, -0.0503, -0.1256,  0.0463, -0.1369,  0.2044, -0.2159, -0.2735,
#           0.0065, -0.2015],
#         [-0.0483,  0.2436, -0.3169, -0.1165, -0.2055,  0.0280,  0.0193, -0.0308,
#           0.2857,  0.2830],
#         [ 0.0815,  0.1772, -0.2250,  0.2802, -0.0820, -0.2324,  0.0587,  0.1061,
#           0.0969, -0.2247],
#         [-0.0599,  0.2713, -0.1362, -0.3218,  0.0048,  0.1499, -0.2335, -0.1296,
#          -0.2241,  0.0815],
#         [-0.2760,  0.2446,  0.1084, -0.0535, -0.2270,  0.1394,  0.2047,  0.1401,
#          -0.1613, -0.1604],
#         [ 0.2534,  0.2819,  0.1767, -0.2600,  0.2412,  0.2956, -0.2568,  0.1911,
#           0.1224, -0.2625],
#         [ 0.1638, -0.1228,  0.2937,  0.2147,  0.0025, -0.0263,  0.0429,  0.2788,
#          -0.1587, -0.3249],
#         [-0.2593,  0.1374,  0.0983, -0.2508, -0.1650, -0.2545, -0.3302, -0.0210,
#          -0.3218, -0.0797],
#         [-0.1601, -0.1997,  0.2946,  0.2120,  0.1702, -0.2990, -0.2365,  0.2234,
#          -0.0430,  0.0581],
#         [ 0.1863,  0.1267,  0.2457, -0.0212, -0.2282, -0.0653,  0.1385,  0.2210,
#          -0.2072,  0.0434],
#         [-0.4797, -0.0696, -0.2014, -0.1056,  0.4809,  0.1941, -0.1646,  0.1075,
#          -0.0965, -0.0469],
#         [-0.5185, -0.1337, -0.0912, -0.1395,  0.2148, -0.1700, -0.2500,  0.2137,
#          -0.0615,  0.2286],
#         [-0.3262, -0.2102, -0.2630,  0.2643, -0.0643,  0.0691, -0.2727, -0.2590,
#          -0.0480,  0.2881],
#         [ 0.1000,  0.1867, -0.2458,  0.1432, -0.1766, -0.3148, -0.0317,  0.2565,
#          -0.2400, -0.2008]])
# linear2.bias tensor([ 0.3064, -0.1268, -0.1791,  0.2450, -0.1277, -0.0318, -0.0444,  0.0790,
#         -0.1901,  0.1437,  0.0694,  0.0895, -0.2746, -0.0906,  0.1505, -0.1587,
#          0.1318,  0.2136, -0.2662, -0.0611])
# linear3.weight tensor([[ 0.0243, -0.0236, -0.1523, -0.2138, -0.2357,  0.0157,  0.2568, -0.0117,
#          -0.0365, -0.1601,  0.0274,  0.0059,  0.1388, -0.3169, -0.1574,  0.0362,
#          -0.5938, -0.6136, -0.3708, -0.0061],
#         [-0.2118,  0.1843,  0.0939, -0.0796,  0.1185, -0.2506, -0.1452, -0.0485,
#          -0.0737,  0.1901,  0.1620,  0.0532,  0.1340,  0.1258, -0.0021, -0.1726,
#           0.1671,  0.0938,  0.1027,  0.1823]])
# linear3.bias tensor([ 0.0142, -0.1971])
# tensor([[0., 1.],
#         [0., 0.],
#         [0., 1.],
#         [0., 0.]], grad_fn=<RoundBackward0>)

# %%
calculatePerformancePrint(model4Linear, 1000, data_in, data_target)
# Out:
# Epoch [100/1000], Loss: 0.2188
# Epoch [200/1000], Loss: 0.2188
# Epoch [300/1000], Loss: 0.2188
# Epoch [400/1000], Loss: 0.2188
# Epoch [500/1000], Loss: 0.2188
# Epoch [600/1000], Loss: 0.2188
# Epoch [700/1000], Loss: 0.2188
# Epoch [800/1000], Loss: 0.2188
# Epoch [900/1000], Loss: 0.2188
# Epoch [1000/1000], Loss: 0.2188
# Test Accuracy: 62.50%
# linear1.weight tensor([[-0.3285,  0.1746],
#         [-0.2605,  0.1918]])
# linear1.bias tensor([0.5786, 0.4453])
# linear2.weight tensor([[-0.3003,  0.5405],
#         [ 0.5478, -0.1952],
#         [ 0.3071,  0.0802]])
# linear2.bias tensor([ 0.3921, -0.3316, -0.6469])
# linear3.weight tensor([[-0.0727, -0.3268,  0.3500],
#         [ 0.2115,  0.3132,  0.2553],
#         [-0.5021, -0.4258, -0.5600],
#         [-0.5481, -0.3902,  0.1057]])
# linear3.bias tensor([-0.3466,  0.3983,  0.0744,  0.4513])
# linear4.weight tensor([[ 0.0144, -0.0166, -0.2250, -0.2344],
#         [-0.0303,  0.1921, -0.1131,  0.0821]])
# linear4.bias tensor([-0.9016, -0.1216])
# tensor([[0., 1.],
#         [0., 1.],
#         [0., 0.],
#         [0., 0.]], grad_fn=<RoundBackward0>)
